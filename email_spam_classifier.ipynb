# %%
import numpy as np 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('emails.csv')

# %%
df.head()
# Out:
#                                                 Text  Spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
df.shape
# Out:
# (5728, 2)

# %%
df = df.iloc[:,0:2]

# %%
df.sample(10)
# Out:
#                                                    Text  Spam
# 1109  Subject: does your business depend on the onli...     1
# 4013  Subject: re : wharton business plan competitio...     0
# 4307  Subject: re : network planning  stinson , i ha...     0
# 4849  Subject: welcome to - energy news live  dear v...     0
# 3916  Subject: petrochem desk  i had a chance to spe...     0
# 198   Subject: online live striptease for you  see m...     1
# 2752  Subject: re : country risk jr . economist hiri...     0
# 3154  Subject: your approval is overdue : access req...     0
# 4267  Subject: re : turkey  the group to whom this m...     0
# 2307  Subject: real options conference programs ( uc...     0

# %%
df.isnull().sum()
# Out:
# Text    0
# Spam    0
# dtype: int64

# %%
df.shape
# Out:
# (5728, 2)

# %%
df.duplicated().sum()
# Out:
# 33

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (5695, 2)

# %%
df['Spam'].value_counts()
# Out:
# 0    4327
# 1    1368
# Name: Spam, dtype: int64

# %%
L=[]
for i in df['Text'].values:
    L.extend(i.split())
L = list(set(L))

# %%
L
# Out:
# ['messages',
#  'berryman',
#  'corpc',
#  'trials',
#  '33841',
#  'gorny',
#  'flashmail',
#  'extremely',
#  'shelley',
#  '3181',
#  'repayment',
#  'kaminksi',
#  'marty',
#  'shear',
#  'nt',
#  'nomorel',
#  'ow',
#  'weapon',
#  'kathryn',
#  '8010',
#  'most',
#  'banque',
#  'faster',
#  'einem',
#  'dupree',
#  'zobaczenie',
#  'advisable',
#  '171',
#  'desk',
#  'epc',
#  'interface',
#  'biometric',
#  'alluvium',
#  'incease',
#  'convenience',
#  'interchange',
#  'firstly',
#  'fitted',
#  'rapidsite',
#  'bunker',
#  'finalizing',
#  'autrey',
#  'aawesome',
#  'paymentshome',
#  'robison',
#  'revs',
#  'polished',
#  'horst',
#  'mofongo',
#  'powienien',
#  'yzaguirre',
#  'civel',
#  '8357',
#  'jenkintown',
#  'develop',
#  'ocn',
#  'absolved',
#  'solved',
#  'madison',
#  'vnbl',
#  '07828',
#  'lincoln',
#  '570',
#  'doubled',
#  '05',
#  'mora',
#  'daemon',
#  'magic',
#  'annuities',
#  'miiiion',
#  '6521',
#  'smile',
#  'mentality',
#  '39510',
#  'stationed',
#  'henderson',
#  'diss',
#  'wisdomthat',
#  'dexter',
#  'preferance',
#  'hanno',
#  'coat',
#  'uyz',
#  'gnu',
#  'morphology',
#  'employees',
#  'fiala',
#  'q',
#  'stronke',
#  'maintenant',
#  'officicals',
#  'anonymously',
#  'unpretending',
#  '09359984',
#  '8141',
#  'collapse',
#  'kayieen',
#  'protesting',
#  'entr?es',
#  'taxonomy',
#  'maclean',
#  'aimone',
#  'rubberized',
#  '283',
#  'carrot',
#  'isn',
#  'impediments',
#  'prinzipiell',
#  'kopie',
#  'exceedingly',
#  'nita',
#  'recognise',
#  '3326',
#  'rapidly',
#  'authorization',
#  'satisfactory',
#  'sinatown',
#  'kure',
#  'stalker',
#  'testing',
#  'vladimir',
#  'imbalance',
#  'position',
#  'barry',
#  '3991',
#  'multidisciplinary',
#  '3327373',
#  'directing',
#  'almelo',
#  'guerriero',
#  'pleus',
#  'thoughtfulness',
#  'commands',
#  '4215',
#  'buildinq',
#  'differentiate',
#  'money',
#  'morenewslettersl',
#  '30516641',
#  'guarding',
#  'merriss',
#  'fla',
#  'seaborne',
#  'geoscience',
#  'dahomey',
#  'bureaus',
#  'plantar',
#  'media',
#  'portion',
#  '1333395',
#  'weened',
#  'coffman',
#  'mentioned',
#  '3491',
#  'jayde',
#  '5214',
#  'makepretty',
#  'jjw',
#  'importados',
#  'nocy',
#  'manlove',
#  'ccisol',
#  'ebook',
#  'rotenberbg',
#  'debtor',
#  'cyberverse',
#  '3518',
#  'udadza',
#  '29',
#  'feedds',
#  'hint',
#  'intrests',
#  '4841424152',
#  'slighted',
#  'ive',
#  '894',
#  'ocl',
#  'philipp',
#  'ron',
#  'ramon',
#  'cayman',
#  'bell',
#  'podeslana',
#  'hypnotic',
#  'qmqp',
#  'gamlng',
#  '3458',
#  'roses',
#  'regulate',
#  'quasi',
#  'cmzcqj',
#  'mhuang',
#  'hydro',
#  '287',
#  'ich',
#  'globo',
#  'enerprise',
#  'profitabie',
#  'auc',
#  'retai',
#  'bellinghausen',
#  'baseline',
#  'silva',
#  'gwynn',
#  'latham',
#  'chistie',
#  'locations',
#  'syacmorenet',
#  'answers',
#  '2005071819',
#  'alison',
#  'careerbuilder',
#  'ccgt',
#  'thoughtful',
#  'underlining',
#  'longman',
#  'tuning',
#  'lazy',
#  'nicelywhen',
#  'jolly',
#  'osman',
#  'chatrooms',
#  'acknowledging',
#  'studentow',
#  'declining',
#  'making',
#  'preformatted',
#  '150',
#  'mineral',
#  'improves',
#  'caught',
#  'mshow',
#  'eaton',
#  'pi',
#  'levy',
#  '569',
#  'grindery',
#  '13417514',
#  'lays',
#  'marc',
#  'bust',
#  'intl',
#  'dean',
#  'opt',
#  'confusing',
#  'rfid',
#  'unfavorable',
#  'colored',
#  'unscheduled',
#  'adminscript',
#  'zidar',
#  '0543',
#  'brownlee',
#  'whil',
#  'siemens',
#  'bantus',
#  'toraise',
#  '5117',
#  'fow',
#  'oof',
#  'glownym',
#  'bledow',
#  'destinataire',
#  'contentions',
#  'dignitaries',
#  'keepers',
#  'boom',
#  'palfrey',
#  'wrangler',
#  'meds',
#  'frontier',
#  'englewood',
#  'crighton',
#  'ktt',
#  '400250',
#  'defeatist',
#  'outlining',
#  'socalgas',
#  'deon',
#  '305',
#  'orthodontist',
#  '77042',
#  'agendas',
#  'nonsense',
#  'ended',
#  'rthe',
#  'dresses',
#  'iot',
#  'skarness',
#  'celebrating',
#  '9835',
#  'cts',
#  'epcurvepaper',
#  'mansley',
#  'deteriorating',
#  'antiques',
#  'difficult',
#  '316',
#  'fame',
#  'baza',
#  '0802',
#  'strating',
#  '98',
#  'malus',
#  'youngest',
#  'bodies',
#  'uhc',
#  'gilda',
#  'fournais',
#  'exhibits',
#  'hungary',
#  'celebrate',
#  'haricotbean',
#  'stating',
#  'pjmcur',
#  'aspijk',
#  'gory',
#  'ministry',
#  'feeling',
#  'ddominic',
#  'jouney',
#  'vshanbh',
#  'swanson',
#  'oacevlmg',
#  'medzo',
#  'deepen',
#  'relocations',
#  'hugely',
#  'ultimatum',
#  'contactar',
#  'understated',
#  'anitha',
#  'gus',
#  'rectorial',
#  'gibson',
#  'elaborate',
#  'encrypt',
#  'haffez',
#  'newark',
#  'optimality',
#  'amaze',
#  'prico',
#  'okym',
#  'cellulose',
#  'notions',
#  'joshua',
#  'falls',
#  'unimpressed',
#  'pasadena',
#  'proponuje',
#  'weldon',
#  '1988',
#  'hormones',
#  'requiremus',
#  'netflix',
#  'sprintpcs',
#  'strychnine',
#  'constitutes',
#  'decoration',
#  'soth',
#  '3719010',
#  '01928923',
#  'acquiring',
#  'edit',
#  '2523',
#  'stocastic',
#  'recording',
#  'cohrs',
#  'beacon',
#  'sherrick',
#  'merck',
#  'vacant',
#  'patriot',
#  'ennron',
#  'differentials',
#  'achievement',
#  '4263',
#  'chart',
#  'outlookindia',
#  'fritch',
#  'arbitrators',
#  'phosgene',
#  'sgibner',
#  'boatyard',
#  'saundry',
#  '937',
#  'caltech',
#  'tif',
#  'labhart',
#  '20052',
#  'ries',
#  'libel',
#  'baddest',
#  '320',
#  'abnegate',
#  'haben',
#  'skontaktowania',
#  'architect',
#  'excessive',
#  '4746',
#  'pepsi',
#  'metallic',
#  'ted',
#  'nicely',
#  'bloxz',
#  'helina',
#  'bonfire',
#  'displacing',
#  'viral',
#  'lecture',
#  'bohn',
#  'columbo',
#  'turbocharged',
#  'goldfinch',
#  '9609',
#  'scholes',
#  'gahn',
#  'goal',
#  '30423',
#  'muffle',
#  '64',
#  'oget',
#  'ezequiel',
#  'banian',
#  'infancy',
#  'intial',
#  'deseje',
#  'wrapping',
#  'glossitis',
#  'painfully',
#  'contacting',
#  'correspondence',
#  'hisd',
#  '1697',
#  'symes',
#  '8167',
#  'follows',
#  'lucia',
#  'destitution',
#  'faliure',
#  'venkat',
#  'inexplicit',
#  'trecento',
#  'fisted',
#  'internetweek',
#  '68060',
#  'epidemic',
#  'computable',
#  'optspreadopt',
#  'fasb',
#  'betrothal',
#  'promotional',
#  'garbage',
#  'presenter',
#  'augmented',
#  'message',
#  'reintroduce',
#  '20004',
#  'revive',
#  'waukesha',
#  'resistence',
#  '33345',
#  'trough',
#  'valuation',
#  'recipe',
#  'aseveru',
#  'flavel',
#  'taping',
#  'devotes',
#  'ecological',
#  'dickerson',
#  'ceramium',
#  '76',
#  'storing',
#  'securities',
#  'hugs',
#  'yard',
#  'globalization',
#  'apparent',
#  'hp',
#  'statical',
#  'chrome',
#  '278312',
#  'zoe',
#  'guides',
#  'howe',
#  'freepage',
#  'faith',
#  'quebec',
#  'following',
#  'iota',
#  'envifi',
#  'favor',
#  'erp',
#  'von',
#  'optical',
#  'tale',
#  'simonnemayer',
#  'bodyshape',
#  'expressions',
#  'homegenous',
#  'demoralizing',
#  'neighbouring',
#  'patina',
#  'cockpit',
#  'upshaw',
#  'headings',
#  'strategies',
#  'lilia',
#  'injecting',
#  'exposing',
#  'tetm',
#  'pcl',
#  'prohibits',
#  'elasticity',
#  'zainteresuje',
#  'relying',
#  'universally',
#  'ratcliff',
#  'winkelman',
#  'tangential',
#  'her',
#  'voltage',
#  'simulate',
#  'eep',
#  'merchandising',
#  'creditors',
#  'springmorqan',
#  'een',
#  '2282',
#  '2631',
#  'correctly',
#  'coffer',
#  'lopez',
#  'seperately',
#  'established',
#  'martha',
#  'varpro',
#  'terraces',
#  'rbl',
#  'matt',
#  'mote',
#  'brother',
#  'witty',
#  '86256525',
#  'tops',
#  'enroll',
#  'australasia',
#  'ridge',
#  'officer',
#  'ionqing',
#  'resl',
#  'tany',
#  'mcgreevy',
#  'executables',
#  'apply',
#  'exampies',
#  'qsri',
#  'hrgovcic',
#  'postions',
#  'puc',
#  'designated',
#  'transports',
#  'optimized',
#  'detailed',
#  '4970',
#  'dutt',
#  'aaron',
#  'ee',
#  'queen',
#  'ondreko',
#  'extraa',
#  'such',
#  'hangar',
#  'rainy',
#  'candatites',
#  'collateral',
#  'tego',
#  'knetzger',
#  'wszystko',
#  'gudgets',
#  'adler',
#  'niif',
#  'fkarbar',
#  'rarely',
#  'nodding',
#  'thnaks',
#  'steak',
#  'usd',
#  'notation',
#  'fh?mhair',
#  'edgartown',
#  'miles',
#  'queensl',
#  'tynisha',
#  'eliminate',
#  'quickbooks',
#  'hotel',
#  'nest',
#  '\x12',
#  'env?an',
#  'thusday',
#  'possession',
#  'occupation',
#  'trucks',
#  'cheyenne',
#  'waiver',
#  'associtates',
#  'advice',
#  'analizy',
#  'skepticism',
#  'freezing',
#  'czlonkow',
#  'oceanography',
#  'collegues',
#  'workhorses',
#  'instantly',
#  'opening',
#  'freelinksnetwork',
#  'wigner',
#  'jacindamaddox',
#  'dni',
#  'western',
#  '8300',
#  'dianne',
#  'millstone',
#  'wonderful',
#  '489',
#  'broch',
#  'nely',
#  '16822',
#  'opened',
#  'patterns',
#  'seldom',
#  'treatement',
#  'zainteresowanie',
#  'coca',
#  'cradle',
#  'aus',
#  'zigo',
#  'leading',
#  'load',
#  '068',
#  'inputted',
#  '74206',
#  'buoyancy',
#  'nurse',
#  'discerning',
#  'ecth',
#  'soreness',
#  'piecemeal',
#  '5193',
#  '1955',
#  'monline',
#  'aaaenerfax',
#  'rebekah',
#  'nodded',
#  'powerful',
#  'solving',
#  'ka',
#  'trisha',
#  'slam',
#  'deviate',
#  'wyniku',
#  'showing',
#  'courtesy',
#  'disc',
#  'brown',
#  'roullette',
#  'summertime',
#  'wheelng',
#  'underscoring',
#  'epilogue',
#  'ham',
#  'expo',
#  'dasovich',
#  'preferably',
#  'vaidaweeks',
#  'opted',
#  '3719007',
#  'artificially',
#  'ntiaiity',
#  'ov',
#  'siegel',
#  'adel',
#  'apv',
#  'jamal',
#  'dawson',
#  'oversight',
#  'liveried',
#  'mellifluous',
#  'slotl',
#  'chocolate',
#  'mia',
#  'neda',
#  '76798',
#  'treated',
#  'avoided',
#  'dragging',
#  'stevenson',
#  'economical',
#  'pracami',
#  'pezentacja',
#  'abuse',
#  'rohauer',
#  'cotonou',
#  'darussalam',
#  'shruti',
#  '2768',
#  'rldwide',
#  'disciplining',
#  'attaching',
#  'yesterday',
#  'caly',
#  '185531',
#  'andres',
#  'wallpaper',
#  'recruiting',
#  'sp',
#  'asistant',
#  'sheaffer',
#  'ensilage',
#  'trigger',
#  'piero',
#  'fxaro',
#  'mannually',
#  'excelleent',
#  'supervised',
#  '4703',
#  'admonition',
#  'remaining',
#  '491',
#  '6633',
#  'bib',
#  'more',
#  'holmbury',
#  'revival',
#  'seiche',
#  'birches',
#  '2935',
#  'puerile',
#  'astute',
#  'coalite',
#  '944',
#  '7105',
#  'metromediaenergy',
#  'silently',
#  'corr',
#  'dislodge',
#  'strategy',
#  'mepr',
#  'pooling',
#  '4747',
#  '1079',
#  'podczas',
#  'directcustserve',
#  'eurobonds',
#  'uncover',
#  'totty',
#  'translated',
#  '63',
#  '2085',
#  'attent',
#  'maximing',
#  'intention',
#  'louie',
#  '502876',
#  'rigs',
#  'lian',
#  'earnbigmoney',
#  'setup',
#  'rome',
#  'ccj',
#  'pimples',
#  'compliance',
#  'gerson',
#  'bowl',
#  'reimbursements',
#  'priced',
#  'businessman',
#  '4545',
#  '4277',
#  'jgsfss',
#  'pradyumna',
#  '4881',
#  'regulation',
#  'allison',
#  'ept',
#  'schertz',
#  'weekend',
#  'randomly',
#  'burg',
#  'sullies',
#  'german',
#  'biznesem',
#  'mcarthy',
#  'pubiication',
#  'variations',
#  'swatch',
#  'intentionally',
#  'confrim',
#  'exposition',
#  'traveling',
#  'erbeaten',
#  'buzzword',
#  'subsets',
#  'entre',
#  'phantasmagoria',
#  'infobases',
#  'gunslinger',
#  'games',
#  'regards',
#  'managementupdate',
#  'truiy',
#  'confirms',
#  'milton',
#  'fabricante',
#  'oretech',
#  '896',
#  'above',
#  'fortress',
#  '71100',
#  'seas',
#  'es',
#  'constituted',
#  'prosym',
#  'realigned',
#  'zonings',
#  'bellsouth',
#  'pop',
#  'westbrook',
#  'recourse',
#  'ricoh',
#  'perfected',
#  'bore',
#  'popracowac',
#  'cadent',
#  'huaguang',
#  'uttar',
#  'worked',
#  '3667',
#  'shopnow',
#  'wondered',
#  '4133',
#  'highlight',
#  'seth',
#  'necroscopy',
#  'ripping',
#  'geplant',
#  'frios',
#  'numeric',
#  'refining',
#  'hipping',
#  'wasn',
#  'inw',
#  'highprice',
#  'eclipse',
#  'savage',
#  'collegiality',
#  'divelbiss',
#  'kalotay',
#  'condensed',
#  'whitehill',
#  '30891',
#  'ermes',
#  'bethurem',
#  'dotyczacych',
#  'chorn',
#  '416',
#  '430',
#  '3820',
#  'badedamola',
#  'samer',
#  'team',
#  'kilkakrotnie',
#  'sweepstakes',
#  'anomalies',
#  'nag',
#  'bhadra',
#  'pierre',
#  'november',
#  'aso',
#  'elegantly',
#  'credentials',
#  'resistance',
#  'nailer',
#  'concetta',
#  'gea',
#  'endorsement',
#  '30309',
#  'lauri',
#  'haunted',
#  'csc',
#  'pll',
#  'requestor',
#  'fix',
#  'kitlelere',
#  'koo',
#  'runshi',
#  'exclusivamente',
#  'dellaca',
#  'hagler',
#  'rueckfragen',
#  'relating',
#  'hu',
#  'lcunningham',
#  'shults',
#  'download',
#  'brochures',
#  'hydrargyrum',
#  'exercises',
#  'ceraweek',
#  'saturated',
#  'finansowej',
#  'patel',
#  'excerpts',
#  'clo',
#  'laura',
#  'zgc',
#  'deangelo',
#  'offerhigher',
#  'optimization',
#  'peopie',
#  'hulkjr',
#  'vargo',
#  'restraint',
#  'subsidize',
#  'preschool',
#  'tests',
#  'quants',
#  'lv',
#  'significantly',
#  '3483',
#  'houses',
#  'lewis',
#  'hollow',
#  'eula',
#  'attachment',
#  'believing',
#  '1092',
#  'vandy',
#  'pharmaceuti',
#  'measurement',
#  'kiedy',
#  'pharmon',
#  'zlotych',
#  'rosenberg',
#  'permanent',
#  'jshaw',
#  'eni',
#  'transit',
#  '589',
#  'breakthrough',
#  'follow',
#  'gullibility',
#  'pacmembers',
#  'dod',
#  '430928',
#  'protector',
#  'nigerian',
#  'du',
#  'overseas',
#  'desoto',
#  '9498132241',
#  'citicorp',
#  'myung',
#  'cure',
#  'n',
#  'ba?vurmay?',
#  'mmfoss',
#  'countless',
#  'intercontinental',
#  'btu',
#  'characters',
#  'xpng',
#  'andmuch',
#  'hronline',
#  'seu',
#  'socal',
#  'oslo',
#  'indirect',
#  'nap',
#  'reshaping',
#  'deutschen',
#  'mtpi',
#  'encounters',
#  '464',
#  'sits',
#  'registerded',
#  'ostatni',
#  '156074',
#  '8838',
#  'edyleland',
#  'grupe',
#  'dvdcopyxp',
#  '8594030',
#  '8102',
#  'videotape',
#  'przypomina',
#  'cultivating',
#  ...]

# %%
#text preprocessing
#small letters
#remove special characters
#remove stopwords
#convert to vector

# %%
df['Text'] = df['Text'].apply( lambda x : x.lower())

# %%
df.head()
# Out:
#                                                 Text  Spam
# 0  subject: naturally irresistible your corporate...     1
# 1  subject: the stock trading gunslinger  fanny i...     1
# 2  subject: unbelievable new homes made easy  im ...     1
# 3  subject: 4 color printing special  request add...     1
# 4  subject: do not have money , get software cds ...     1

# %%
def remove_special_chars(text):
    result = ""
    for i in text:
        if i.isalnum() or i ==' ':
            result = result + i
        else:
            result = result + ""
    return result.strip()

# %%
df['Text'] = df['Text'].apply(remove_special_chars)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(stop_words='english',max_features = 10000)

# %%
X = cv.fit_transform(df['Text']).toarray()

# %%
y = df['Spam'].values.astype('int')

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
y.shape
# Out:
# (5695,)

# %%
X.shape
# Out:
# (5695, 10000)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB()

# %%
clf.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9885864793678666

# %%
import pickle

# %%
pickle.dump(cv,open('cv.pkl','wb'))
pickle.dump(clf,open('clf.pkl','wb'))
